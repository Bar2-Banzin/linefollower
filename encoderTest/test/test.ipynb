# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import math
import pandas as pd

# %matplotlib%
# qt <=> inline
# Out:
# UsageError: Line magic function `%matplotlib%` not found.

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    ## HINT 1: How is the data ordered in the file?
    ## HINT 2: Do you need to cast the data you read from the file?
    data = None
    data = pd.read_csv(file_name, sep=',', header=None)
    return data

# %%
def read_test_data(filename):
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?

    test_data = pd.read_csv(filename, sep=',', header=None)

    return test_data

# %%
#Kp = 0.7
print("kp = 0.7 - kd = 0")
var = np.asarray(read_test_data('run1.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 0.9
print("kp = 0.9 - kd = 0")
var = np.asarray(read_test_data('run2.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1
print("kp = 1 - kd = 0")
var = np.asarray(read_test_data('run5.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1, Kd = 4
print("kp = 1 - kd = 4")
var = np.asarray(read_test_data('run6.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1.2
print("kp = 1.2 - kd = 0")
var = np.asarray(read_test_data('run3.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1.5
print("kp = 1.5 - kd = 0")
var = np.asarray(read_test_data('run4.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1.5, kd = 2
print("kp = 1.5 - kd = 2")
var = np.asarray(read_test_data('run7.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1.5, kd = 0.5
print("kp = 1.5 - kd = 0.5")
var = np.asarray(read_test_data('run8.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1.5, kd = 1.1
print("kp = 1.5 - kd = 1.1")
var = np.asarray(read_test_data('run9.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 1.5, kd = 0.9
print("kp = 1.5 - kd = 0.9")
var = np.asarray(read_test_data('run10.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()

#Kp = 2, kd = 0
print("kp = 2 - kd = 0")
var = np.asarray(read_test_data('run11.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()


print("kp = 0.75 - ki = 0.75")
var = np.asarray(read_test_data('run12.csv'))
setpoint=var[:,0]
outputRPM=var[:,1]
pwm=var[:,2]
time = var[:,3]
# print(setpoint)
plt.plot(time, setpoint, c = 'r')
plt.plot(time, outputRPM, c = 'g')
plt.show()
# Out:
# kp = 0.7 - kd = 0
# kp = 0.9 - kd = 0
# kp = 1 - kd = 0
# kp = 1 - kd = 4
# kp = 1.2 - kd = 0
# kp = 1.5 - kd = 0
# kp = 1.5 - kd = 2
# kp = 1.5 - kd = 0.5
# kp = 1.5 - kd = 1.1
# kp = 1.5 - kd = 0.9
# kp = 2 - kd = 0
# kp = 0.75 - ki = 0.75
